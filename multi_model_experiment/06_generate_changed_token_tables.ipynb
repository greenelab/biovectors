# %% [markdown]
# # Generate Tables of the Most Changed Tokens

# %%
# %load_ext autoreload
# %autoreload 2

from pathlib import Path
import re

import numpy as np
import pandas as pd
import plotnine as p9
import plydata as ply
import plydata.tidy as ply_tdy
import tqdm

# %%
subsetted_tokens = pd.read_csv("output/subsetted_tokens.tsv", sep="\t")
token_filter_list = subsetted_tokens.tok.tolist()
subsetted_tokens.head()
# Out:
#              tok
# 0         united
# 1      combining
# 2     purinergic
# 3  decomposition
# 4           60.0

# %%
distance_files = list(
    Path("output/combined_inter_intra_distances").rglob("saved_*_distance.tsv")
)
print(len(distance_files))
# Out:
# 20

# %%
year_distance_map = {
    re.search(r"\d+", str(year_file)).group(0): (pd.read_csv(str(year_file), sep="\t"))
    for year_file in tqdm.tqdm(distance_files)
}
# Out:
# 100%|██████████| 20/20 [00:02<00:00,  8.48it/s]

# %%
full_token_set_df = pd.concat(
    [
        year_distance_map[year] >> ply.query(f"tok in {token_filter_list}")
        # >>ply.query("year_2-year_1 == 1")
        >> ply.query("year_1 == 2000")
        for year in tqdm.tqdm(year_distance_map)
    ]
)
print(full_token_set_df.shape)
full_token_set_df.head()
# Out:
# 100%|██████████| 20/20 [00:12<00:00,  1.58it/s]
# (298840, 8)
#              tok  original_global_distance  global_distance_qst  \
# 0         united                  0.710870             0.737019
# 1      combining                  0.742832             0.867140
# 2     purinergic                  0.710384             0.652537
# 3  decomposition                  0.886063             0.776245
# 4           60.0                  0.783535             0.650033
#
#    global_times_distance_qst  local_distance_qst  local_times_distance_qst  \
# 0                   0.523925            0.924041                  0.302456
# 1                   0.644140            0.997836                  0.599636
# 2                   0.463552            0.930912                  0.232051
# 3                   0.687802            0.966696                  0.489906
# 4                   0.509323            0.794930                  0.376786
#
#    year_1  year_2
# 0    2000    2017
# 1    2000    2017
# 2    2000    2017
# 3    2000    2017
# 4    2000    2017

# %% [markdown]
# # Top Ten Words that has the Greatest Rate of Change in X time

# %% [markdown]
# ## 20 Years

# %%
(
    full_token_set_df
    >> ply.query("year_2==2020")
    >> ply.arrange("-global_distance_qst")
    >> ply.slice_rows(10)
)
# Out:
#             tok  original_global_distance  global_distance_qst  \
# 76308  evaluate                  0.516028             0.935680
# 82811      lead                  0.597169             0.931792
# 85871  provided                  0.757996             0.928921
# 81768   improve                  0.499031             0.928311
# 78573  analysis                  0.519404             0.928257
# 85062      aims                  0.822279             0.928231
# 86740     using                  0.388449             0.927692
# 76097  provides                  0.581117             0.925621
# 88715      used                  0.353814             0.924825
# 74868    assess                  0.465595             0.924650
#
#        global_times_distance_qst  local_distance_qst  \
# 76308                   0.482837            0.998775
# 82811                   0.556437            0.999522
# 85871                   0.704118            0.999163
# 81768                   0.463256            0.999111
# 78573                   0.482141            0.998019
# 85062                   0.763265            0.999160
# 86740                   0.360361            0.997601
# 76097                   0.537894            0.998985
# 88715                   0.327216            0.997529
# 74868                   0.430512            0.997826
#
#        local_times_distance_qst  year_1  year_2
# 76308                  0.266206    2000    2020
# 82811                  0.462440    2000    2020
# 85871                  0.621590    2000    2020
# 81768                  0.243595    2000    2020
# 78573                  0.304060    2000    2020
# 85062                  0.694036    2000    2020
# 86740                  0.105174    2000    2020
# 76097                  0.365198    2000    2020
# 88715                  0.085798    2000    2020
# 74868                  0.198380    2000    2020

# %%
(
    full_token_set_df
    >> ply.query("year_2==2020")
    >> ply.arrange("-original_global_distance")
    >> ply.slice_rows(10)
)
# Out:
#                   tok  original_global_distance  global_distance_qst  \
# 87260  reintroduction                  1.172329             0.749579
# 88498       authentic                  1.163812             0.706494
# 76956       reception                  1.152074             0.743327
# 87286           hsp90                  1.129326             0.805121
# 87033      galectin-1                  1.124502             0.748855
# 79700      modifiable                  1.124492             0.783657
# 87579   cephalosporin                  1.118213             0.744903
# 83615             302                  1.108112             0.674808
# 78811      warranting                  1.100526             0.761106
# 87869           theta                  1.098731             0.800358
#
#        global_times_distance_qst  local_distance_qst  \
# 87260                   0.878753            0.954574
# 88498                   0.822225            0.932284
# 76956                   0.856367            0.974451
# 87286                   0.909244            0.981617
# 87033                   0.842089            0.970340
# 79700                   0.881217            0.975328
# 87579                   0.832960            0.958520
# 83615                   0.747762            0.871606
# 78811                   0.837617            0.986673
# 87869                   0.879378            0.976841
#
#        local_times_distance_qst  year_1  year_2
# 87260                  1.370600    2000    2020
# 88498                  1.457587    2000    2020
# 76956                  1.524101    2000    2020
# 87286                  1.392923    2000    2020
# 87033                  1.219711    2000    2020
# 79700                  1.381839    2000    2020
# 87579                  1.271859    2000    2020
# 83615                  1.055087    2000    2020
# 78811                  1.277611    2000    2020
# 87869                  1.160200    2000    2020

# %%
(
    full_token_set_df
    >> ply.query("year_2==2020")
    >> ply.arrange("-global_times_distance_qst")
    >> ply.slice_rows(10)
)
# Out:
#                   tok  original_global_distance  global_distance_qst  \
# 84148        inspired                  1.080367             0.852893
# 75215           warts                  1.098490             0.838215
# 80787         warrant                  1.033638             0.884563
# 87286           hsp90                  1.129326             0.805121
# 80800      imbalances                  1.076003             0.844781
# 79268   chronological                  1.094599             0.819024
# 80446  polysaccharide                  1.062721             0.836282
# 78588       meanwhile                  1.019270             0.871004
# 87360    complicating                  1.063107             0.833475
# 79700      modifiable                  1.124492             0.783657
#
#        global_times_distance_qst  local_distance_qst  \
# 84148                   0.921437            0.996255
# 75215                   0.920771            0.996381
# 80787                   0.914318            0.998616
# 87286                   0.909244            0.981617
# 80800                   0.908987            0.997302
# 79268                   0.896503            0.994750
# 80446                   0.888735            0.994943
# 78588                   0.887789            0.998546
# 87360                   0.886073            0.996720
# 79700                   0.881217            0.975328
#
#        local_times_distance_qst  year_1  year_2
# 84148                  1.199118    2000    2020
# 75215                  1.215820    2000    2020
# 80787                  1.106960    2000    2020
# 87286                  1.392923    2000    2020
# 80800                  1.169570    2000    2020
# 79268                  1.215960    2000    2020
# 80446                  1.223538    2000    2020
# 78588                  1.119941    2000    2020
# 87360                  1.205275    2000    2020
# 79700                  1.381839    2000    2020

# %% [markdown]
# ## 10 Years

# %%
(
    full_token_set_df
    >> ply.query("year_2==2010")
    >> ply.arrange("-global_distance_qst")
    >> ply.slice_rows(10)
)
# Out:
#               tok  original_global_distance  global_distance_qst  \
# 217343       lead                  0.590731             0.916682
# 222199        aim                  0.517852             0.913818
# 209521  regulates                  0.519855             0.912533
# 210840   evaluate                  0.469406             0.912293
# 220403   provided                  0.731986             0.903532
# 212319   insights                  0.696888             0.902792
# 210629   provides                  0.545296             0.902554
# 216300    improve                  0.468035             0.898707
# 220666   overview                  0.581666             0.897467
# 209400     assess                  0.446907             0.897432
#
#         global_times_distance_qst  local_distance_qst  \
# 217343                   0.541513            0.999438
# 222199                   0.473223            0.997871
# 209521                   0.474385            0.998892
# 210840                   0.428236            0.998406
# 220403                   0.661373            0.998727
# 212319                   0.629145            0.998179
# 210629                   0.492159            0.998620
# 216300                   0.420627            0.998611
# 220666                   0.522026            0.997338
# 209400                   0.401069            0.997332
#
#         local_times_distance_qst  year_1  year_2
# 217343                  0.439696    2000    2010
# 222199                  0.237291    2000    2010
# 209521                  0.160646    2000    2010
# 210840                  0.212040    2000    2010
# 220403                  0.513804    2000    2010
# 212319                  0.412491    2000    2010
# 210629                  0.299460    2000    2010
# 216300                  0.185910    2000    2010
# 220666                  0.209528    2000    2010
# 209400                  0.170172    2000    2010

# %%
(
    full_token_set_df
    >> ply.query("year_2==2010")
    >> ply.arrange("-original_global_distance")
    >> ply.slice_rows(10)
)
# Out:
#                        tok  original_global_distance  global_distance_qst  \
# 223030           authentic                  1.232631             0.699925
# 222111       cephalosporin                  1.171434             0.751192
# 211488           reception                  1.158616             0.727130
# 213343          warranting                  1.158600             0.738517
# 218147                 302                  1.121088             0.649605
# 213800       chronological                  1.117529             0.790808
# 214232          modifiable                  1.115028             0.763488
# 209747               warts                  1.113944             0.835063
# 216391  neurophysiological                  1.104586             0.761018
# 212113   cardiorespiratory                  1.103337             0.724604
#
#         global_times_distance_qst  local_distance_qst  \
# 223030                   0.862749            0.934346
# 222111                   0.879972            0.962236
# 211488                   0.842465            0.972742
# 213343                   0.855646            0.985463
# 218147                   0.728264            0.873451
# 213800                   0.883751            0.994410
# 214232                   0.851311            0.975392
# 209747                   0.930213            0.996120
# 216391                   0.840610            0.981287
# 212113                   0.799483            0.974697
#
#         local_times_distance_qst  year_1  year_2
# 223030                  1.548255    2000    2010
# 222111                  1.410112    2000    2010
# 211488                  1.499470    2000    2010
# 213343                  1.409410    2000    2010
# 218147                  1.082113    2000    2010
# 213800                  1.303684    2000    2010
# 214232                  1.398058    2000    2010
# 209747                  1.245652    2000    2010
# 216391                  1.113876    2000    2010
# 212113                  1.003954    2000    2010

# %%
(
    full_token_set_df
    >> ply.query("year_2==2010")
    >> ply.arrange("-global_times_distance_qst")
    >> ply.slice_rows(10)
)
# Out:
#                              tok  original_global_distance  \
# 209747                     warts                  1.113944
# 214978            polysaccharide                  1.069924
# 216749                       snp                  1.079064
# 213800             chronological                  1.117529
# 221111                  engineer                  1.009955
# 222111             cephalosporin                  1.171434
# 218680                  inspired                  1.047393
# 219904             intrinsically                  1.099165
# 220463                        1q                  1.064109
# 215085  urinary_tract_infections                  1.092022
#
#         global_distance_qst  global_times_distance_qst  local_distance_qst  \
# 209747             0.835063                   0.930213            0.996120
# 214978             0.844244                   0.903277            0.994854
# 216749             0.829347                   0.894918            0.996658
# 213800             0.790808                   0.883751            0.994410
# 221111             0.874552                   0.883259            0.998931
# 222111             0.751192                   0.879972            0.962236
# 218680             0.836533                   0.876179            0.995060
# 219904             0.793209                   0.871868            0.993911
# 220463             0.818579                   0.871057            0.996815
# 215085             0.791380                   0.864204            0.978088
#
#         local_times_distance_qst  year_1  year_2
# 209747                  1.245652    2000    2010
# 214978                  1.123478    2000    2010
# 216749                  1.177985    2000    2010
# 213800                  1.303684    2000    2010
# 221111                  0.990645    2000    2010
# 222111                  1.410112    2000    2010
# 218680                  1.055819    2000    2010
# 219904                  1.272971    2000    2010
# 220463                  1.025731    2000    2010
# 215085                  1.197908    2000    2010

# %% [markdown]
# ## 5 Years

# %%
(
    full_token_set_df
    >> ply.query("year_2==2005")
    >> ply.arrange("-global_distance_qst")
    >> ply.slice_rows(10)
)
# Out:
#                tok  original_global_distance  global_distance_qst  \
# 269950    database                  0.441206             0.920589
# 271943  alcoholism                  0.807027             0.916653
# 278407   available                  0.454164             0.908269
# 271988       genes                  0.335100             0.904822
# 274706        2000                  0.732539             0.904467
# 281932    isolates                  0.374527             0.903044
# 277197       plant                  0.544530             0.902609
# 271860        sets                  0.560821             0.901533
# 282372    accuracy                  0.423753             0.901511
# 269117     quality                  0.561085             0.900217
#
#         global_times_distance_qst  local_distance_qst  \
# 269950                   0.406169            0.998532
# 271943                   0.739764            0.998662
# 278407                   0.412503            0.997425
# 271988                   0.303206            0.992618
# 274706                   0.662558            0.996325
# 281932                   0.338215            0.996259
# 277197                   0.491498            0.997452
# 271860                   0.505599            0.997879
# 282372                   0.382018            0.997362
# 269117                   0.505098            0.994892
#
#         local_times_distance_qst  year_1  year_2
# 269950                  0.113409    2000    2005
# 271943                  0.617099    2000    2005
# 278407                  0.106403    2000    2005
# 271988                  0.033187    2000    2005
# 274706                  0.358943    2000    2005
# 281932                  0.101537    2000    2005
# 277197                  0.204842    2000    2005
# 271860                  0.206959    2000    2005
# 282372                  0.129582    2000    2005
# 269117                  0.119734    2000    2005

# %%
(
    full_token_set_df
    >> ply.query("year_2==2005")
    >> ply.arrange("-original_global_distance")
    >> ply.slice_rows(10)
)
# Out:
#                           tok  original_global_distance  global_distance_qst  \
# 270534               rapidity                  1.390827             0.832558
# 271403              multisite                  1.384575             0.797236
# 273599            alleviation                  1.371685             0.822157
# 280086              crucially                  1.365927             0.797400
# 274717            temporarily                  1.356807             0.785704
# 277727              medicated                  1.335899             0.758091
# 276990                    cam                  1.327111             0.813342
# 280192                portray                  1.309740             0.783175
# 270466                     nn                  1.293741             0.777745
# 283004  escherichia_coli_k-12                  1.284659             0.777089
#
#         global_times_distance_qst  local_distance_qst  \
# 270534                   1.157944            0.993521
# 271403                   1.103833            0.984556
# 273599                   1.127740            0.991879
# 280086                   1.089189            0.981266
# 274717                   1.066049            0.979975
# 277727                   1.012733            0.960089
# 276990                   1.079396            0.986237
# 280192                   1.025755            0.983585
# 270466                   1.006200            0.971310
# 283004                   0.998294            0.986620
#
#         local_times_distance_qst  year_1  year_2
# 270534                  1.862461    2000    2005
# 271403                  1.835448    2000    2005
# 273599                  1.846013    2000    2005
# 280086                  1.698202    2000    2005
# 274717                  1.689101    2000    2005
# 277727                  1.718998    2000    2005
# 276990                  1.673309    2000    2005
# 280192                  1.671946    2000    2005
# 270466                  1.590031    2000    2005
# 283004                  1.749542    2000    2005

# %%
(
    full_token_set_df
    >> ply.query("year_2==2005")
    >> ply.arrange("-global_times_distance_qst")
    >> ply.slice_rows(10)
)
# Out:
#                 tok  original_global_distance  global_distance_qst  \
# 270534     rapidity                  1.390827             0.832558
# 273599  alleviation                  1.371685             0.822157
# 271403    multisite                  1.384575             0.797236
# 280086    crucially                  1.365927             0.797400
# 276990          cam                  1.327111             0.813342
# 274717  temporarily                  1.356807             0.785704
# 279349       tremor                  1.270109             0.808374
# 280192      portray                  1.309740             0.783175
# 276541          snp                  1.189061             0.859406
# 277727    medicated                  1.335899             0.758091
#
#         global_times_distance_qst  local_distance_qst  \
# 270534                   1.157944            0.993521
# 273599                   1.127740            0.991879
# 271403                   1.103833            0.984556
# 280086                   1.089189            0.981266
# 276990                   1.079396            0.986237
# 274717                   1.066049            0.979975
# 279349                   1.026723            0.988200
# 280192                   1.025755            0.983585
# 276541                   1.021886            0.997166
# 277727                   1.012733            0.960089
#
#         local_times_distance_qst  year_1  year_2
# 270534                  1.862461    2000    2005
# 273599                  1.846013    2000    2005
# 271403                  1.835448    2000    2005
# 280086                  1.698202    2000    2005
# 276990                  1.673309    2000    2005
# 274717                  1.689101    2000    2005
# 279349                  1.634273    2000    2005
# 280192                  1.671946    2000    2005
# 276541                  1.391027    2000    2005
# 277727                  1.718998    2000    2005
